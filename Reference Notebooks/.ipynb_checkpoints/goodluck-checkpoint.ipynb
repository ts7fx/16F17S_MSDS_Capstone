# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
import random
random.seed(8888)

from scipy import stats
from scipy.spatial import distance

# KSE 
def euc_dis(p1,p2):
    a = p1.values
    b = p2.values
    c = np.vstack((a,b))
    dist = distance.pdist(c)
    return float(dist)
def KSE_Test(df, sample_size):
    # initiate two sample dfs, one distance matrix, and one kse score.
    # generate 2 random samples.
    sample1 = df.sample(n = sample_size, replace = False)
    sample2 = df.sample(n = sample_size, replace = False)
    kse_score = [] # empty list to store KSE scores
#   distance_matrix = np.matrix([[None] * int(len(df) * fraction) , 
#                               [None] * int(len(df) * fraction)])
#     distance_matrix = [[0 for x in range(len(sample1))] 
#                        for y in range(len(sample2))] 
    distance_matrix = np.zeros((sample_size, sample_size))
    # calculate distance from all points in sample1 to all points in sample2
    for i in range(0,sample_size):
        for j in range(0,sample_size):
            distance_matrix[i][j] = euc_dis(sample1.iloc[i,],sample2.iloc[j,])
    # calculate average KS-score for each instance in df.
    for i in range(0, len(df)):
        observed_instance = df.iloc[i,]
        distance_array = [0] * sample_size
        for j in range(0,sample_size):
            distance_array[j] = euc_dis(observed_instance,sample2.iloc[j,])
        sum = 0
        for k in range(0, sample_size):
            ks_score = stats.ks_2samp(distance_array, distance_matrix[k])[0]
            sum += ks_score
        average = sum/sample_size
        #kse_score[i] = average
        kse_score.append((i, average))
#         if (i%1000 == 0):
#             print('loop %s' % i)
    print("done")
    return kse_score 

def iForest(df):
    clf = IsolationForest(max_samples=1000, contamination=0.05,random_state= 5, bootstrap=False)
    clf.fit(df)
    y_pred = clf.predict(df)
    anomalies = df[y_pred == -1]
    return anomalies

def LOF(df):
    clf = LocalOutlierFactor(n_neighbors=20, contamination = 0.05)
    y_pred = clf.fit_predict(df)
    anomalies = df[y_pred == -1]
    return anomalies

def final_result(anom_df):
    kse_result = KSE_Test(anom_df, int(0.5 * len(anom_df)))
    index_anom = [] 
    for i in kse_result:
        if i[1] > 0.4:
            index_anom.append(i[0])
    # final result is a data set of the anomalies of the anomalies
    final = anom_df.iloc[index_anom]
    return final

# %%
mon_normalized = pd.read_csv('~/Desktop/data/normalized/data02_13_morning_Pages_normalized', sep = ',')[["bytes","pkts","dur","rate"]]
tue_normalized = pd.read_csv('~/Desktop/data/normalized/data02_14_morning_Pages_normalized', sep = ',')[["bytes","pkts","dur","rate"]]
wed_normalized = pd.read_csv('~/Desktop/data/normalized/data02_15_morning_Pages_normalized', sep = ',')[["bytes","pkts","dur","rate"]]
thur_normalized = pd.read_csv('~/Desktop/data/normalized/data02_16_morning_Pages_normalized', sep = ',')[["bytes","pkts","dur","rate"]]
fri_normalized = pd.read_csv('~/Desktop/data/normalized/data02_17_morning_Pages_normalized', sep = ',')[["bytes","pkts","dur","rate"]]
mon_normalized.columns = ["Bytes","Pkts","Dur","Rate"]
tue_normalized.columns = ["Bytes","Pkts","Dur","Rate"]
wed_normalized.columns = ["Bytes","Pkts","Dur","Rate"]
thur_normalized.columns = ["Bytes","Pkts","Dur","Rate"]
fri_normalized.columns = ["Bytes","Pkts","Dur","Rate"]


## Anomalous data - iForest
mon_norm_anom = iForest(mon_normalized)
tue_norm_anom = iForest(tue_normalized)
wed_norm_anom = iForest(wed_normalized)
thur_norm_anom = iForest(thur_normalized)
fri_norm_anom = iForest(fri_normalized)

## Anomalous data - LOF
mon_norm_anom_ = LOF(mon_normalized)
tue_norm_anom_ = LOF(tue_normalized)
wed_norm_anom_ = LOF(wed_normalized)
thur_norm_anom_ = LOF(thur_normalized)
fri_norm_anom_ = LOF(fri_normalized)

# %%
# ## Final results - iForest
# mon_norm_final = final_result(mon_norm_anom)
# tue_norm_final = final_result(tue_norm_anom)
# wed_norm_final = final_result(wed_norm_anom)
# thur_norm_final = final_result(thur_norm_anom)
# fri_norm_final = final_result(fri_norm_anom)
# ## Final results - LOF
# mon_norm_final_ = final_result(mon_norm_anom_)
# tue_norm_final_ = final_result(tue_norm_anom_)
# wed_norm_final_ = final_result(wed_norm_anom_)
# thur_norm_final_ = final_result(thur_norm_anom_)
# fri_norm_final_ = final_result(fri_norm_anom_)

# %%
## Find the intersection
mon_intersection = mon_normalized.iloc[list(set(mon_norm_anom.index.values).intersection(set(mon_norm_anom_.index.values)))]
tue_intersection = tue_normalized.iloc[list(set(tue_norm_anom.index.values).intersection(set(tue_norm_anom_.index.values)))]
wed_intersection = wed_normalized.iloc[list(set(wed_norm_anom.index.values).intersection(set(wed_norm_anom_.index.values)))]
thur_intersection = thur_normalized.iloc[list(set(thur_norm_anom.index.values).intersection(set(thur_norm_anom_.index.values)))]
fri_intersection = fri_normalized.iloc[list(set(fri_norm_anom.index.values).intersection(set(fri_norm_anom_.index.values)))]

# %%
#Density plots
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))

sns.distplot(mon_norm_final.bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_norm_final.bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_norm_final.bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_norm_final.bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_norm_final.bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_norm_final.pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_norm_final.pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_norm_final.pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_norm_final.pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_norm_final.pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_norm_final.dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_norm_final.dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_norm_final.dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_norm_final.dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_norm_final.dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_norm_final.rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_norm_final.rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_norm_final.rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_norm_final.rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_norm_final.rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend(loc = 'upper left')
ax_2.legend(loc = 'upper left')
ax_3.legend()
ax_4.legend()

fig.savefig('iForest+KSE.png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6799188a6765> in <module>()
#       1 fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))
#       2
# ----> 3 sns.distplot(mon_norm_final.bytes, label = 'mon', hist=False, ax = ax_1)
#       4 sns.distplot(tue_norm_final.bytes, label = 'tue', hist=False, ax = ax_1)
#       5 sns.distplot(wed_norm_final.bytes, label = 'wed', hist=False,ax = ax_1)
#
# NameError: name 'mon_norm_final' is not defined

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))
fig.suptitle('Distribution plots for anomalies detected by LOF + KSE with average KSE score cutoff 0.3')

sns.distplot(mon_norm_final_.bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_norm_final_.bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_norm_final_.bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_norm_final_.bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_norm_final_.bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_norm_final_.pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_norm_final_.pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_norm_final_.pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_norm_final_.pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_norm_final_.pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_norm_final_.dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_norm_final_.dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_norm_final_.dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_norm_final_.dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_norm_final_.dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_norm_final_.rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_norm_final_.rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_norm_final_.rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_norm_final_.rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_norm_final_.rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend()
ax_2.legend()
ax_3.legend()
ax_4.legend()
fig.savefig('LOF+KSE.png', dpi=300)
# Out:
# /Users/ChineseSamurai/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))

sns.distplot(mon_intersection.Bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_intersection.Bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_intersection.Bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_intersection.Bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_intersection.Bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_intersection.Pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_intersection.Pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_intersection.Pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_intersection.Pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_intersection.Pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_intersection.Dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_intersection.Dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_intersection.Dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_intersection.Dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_intersection.Dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_intersection.Rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_intersection.Rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_intersection.Rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_intersection.Rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_intersection.Rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend(loc = 'upper left')
ax_2.legend(loc = 'upper left')
ax_3.legend()
ax_4.legend()

fig.savefig('intersection.png', dpi=300)
# Out:
# /Users/ChineseSamurai/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))
sns.distplot(mon_norm_anom.Bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_norm_anom.Bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_norm_anom.Bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_norm_anom.Bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_norm_anom.Bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_norm_anom.Pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_norm_anom.Pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_norm_anom.Pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_norm_anom.Pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_norm_anom.Pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_norm_anom.Dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_norm_anom.Dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_norm_anom.Dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_norm_anom.Dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_norm_anom.Dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_norm_anom.Rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_norm_anom.Rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_norm_anom.Rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_norm_anom.Rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_norm_anom.Rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend(loc='upper left')
ax_2.legend(loc='upper left')
ax_3.legend()
ax_4.legend()

start, end = ax_2.get_xlim()
ax_2.xaxis.set_ticks(np.arange(start, end, 0.01))

fig.savefig('iForest.png', dpi=300)
# Out:
# /Users/ChineseSamurai/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))

sns.distplot(mon_norm_anom_.Bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_norm_anom_.Bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_norm_anom_.Bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_norm_anom_.Bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_norm_anom_.Bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_norm_anom_.Pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_norm_anom_.Pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_norm_anom_.Pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_norm_anom_.Pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_norm_anom_.Pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_norm_anom_.Dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_norm_anom_.Dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_norm_anom_.Dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_norm_anom_.Dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_norm_anom_.Dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_norm_anom_.Rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_norm_anom_.Rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_norm_anom_.Rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_norm_anom_.Rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_norm_anom_.Rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend()
ax_2.legend()
ax_3.legend()

ax_4.legend(loc = 'upper left')

start, end = ax_2.get_xlim()
ax_2.xaxis.set_ticks(np.arange(start, end, 0.01))

start, end = ax_3.get_xlim()
ax_3.xaxis.set_ticks(np.arange(start, end, 0.01))
fig.savefig('LOF.png', dpi=300)
# Out:
# /Users/ChineseSamurai/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
fig, (ax_1, ax_2, ax_3, ax_4) = plt.subplots(1, 4, figsize=(12, 5))

sns.distplot(mon_normalized.Bytes, label = 'Mon', hist=False, ax = ax_1)
sns.distplot(tue_normalized.Bytes, label = 'Tue', hist=False, ax = ax_1)
sns.distplot(wed_normalized.Bytes, label = 'Wed', hist=False,ax = ax_1)
sns.distplot(thur_normalized.Bytes, label = 'Thur', hist=False,ax = ax_1)
sns.distplot(fri_normalized.Bytes, label = 'Fri', hist=False,ax = ax_1)

sns.distplot(mon_normalized.Pkts, label = 'Mon', hist=False, ax = ax_2)
sns.distplot(tue_normalized.Pkts, label = 'Tue', hist=False, ax = ax_2)
sns.distplot(wed_normalized.Pkts, label = 'Wed', hist=False,ax = ax_2)
sns.distplot(thur_normalized.Pkts, label = 'Thur', hist=False,ax = ax_2)
sns.distplot(fri_normalized.Pkts, label = 'Fri', hist=False,ax = ax_2)

sns.distplot(mon_normalized.Dur, label = 'Mon', hist=False, ax = ax_3)
sns.distplot(tue_normalized.Dur, label = 'Tue', hist=False, ax = ax_3)
sns.distplot(wed_normalized.Dur, label = 'Wed', hist=False,ax = ax_3)
sns.distplot(thur_normalized.Dur, label = 'Thur', hist=False,ax = ax_3)
sns.distplot(fri_normalized.Dur, label = 'Fri', hist=False,ax = ax_3)

sns.distplot(mon_normalized.Rate, label = 'Mon', hist=False, ax = ax_4)
sns.distplot(tue_normalized.Rate, label = 'Tue', hist=False, ax = ax_4)
sns.distplot(wed_normalized.Rate, label = 'Wed', hist=False,ax = ax_4)
sns.distplot(thur_normalized.Rate, label = 'Thur', hist=False,ax = ax_4)
sns.distplot(fri_normalized.Rate, label = 'Fri', hist=False,ax = ax_4)

ax_1.legend()
ax_2.legend()
ax_3.legend()
ax_4.legend(loc = 'upper left')

start, end = ax_2.get_xlim()
ax_2.xaxis.set_ticks(np.arange(start, end, 0.01))

start, end = ax_3.get_xlim()
ax_3.xaxis.set_ticks(np.arange(start, end, 0.01))

fig.savefig('all.png', dpi=300)
# Out:
# /Users/ChineseSamurai/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
print(np.var(mon_norm_anom.bytes))
print(np.var(tue_norm_anom.bytes))
print(np.var(wed_norm_anom.bytes))
print(np.var(thur_norm_anom.bytes))
print(np.var(fri_norm_anom.bytes))
# Out:
# 0.029820570228958194
# 0.039190525317167595
# 0.034564427055887546
# 0.030040008821620223
# 0.02158882576339538

# %%
np.sqrt(0.03)
# Out:
# 0.17320508075688773

# %%
print(np.var(mon_norm_anom_.bytes))
print(np.var(tue_norm_anom_.bytes))
print(np.var(wed_norm_anom_.bytes))
print(np.var(thur_norm_anom_.bytes))
print(np.var(fri_norm_anom_.bytes))
# Out:
# 0.1470192962872785
# 0.10627346956306617
# 0.09371841209937637
# 0.07723286392935885
# 0.16007902986111366

# %%
print(np.var(mon_norm_anom.pkts))
print(np.var(tue_norm_anom.pkts))
print(np.var(wed_norm_anom.pkts))
print(np.var(thur_norm_anom.pkts))
print(np.var(fri_norm_anom.pkts))
# Out:
# 4.817143425170637e-05
# 4.598017783138986e-05
# 4.821313198427948e-05
# 6.581398506252734e-05
# 4.8942447060971765e-05

# %%
print(np.var(mon_norm_anom_.pkts))
print(np.var(tue_norm_anom_.pkts))
print(np.var(wed_norm_anom_.pkts))
print(np.var(thur_norm_anom_.pkts))
print(np.var(fri_norm_anom_.pkts))
# Out:
# 4.239411660386289e-05
# 2.8886337832844454e-05
# 2.9388943749881033e-05
# 2.2977524802951473e-05
# 5.6785232576412474e-05

# %%
print(np.var(mon_norm_anom.dur))
print(np.var(tue_norm_anom.dur))
print(np.var(wed_norm_anom.dur))
print(np.var(thur_norm_anom.dur))
print(np.var(fri_norm_anom.dur))
# Out:
# 6.81499247224496e-05
# 2.4677989777068734e-05
# 1.8630551051547617e-05
# 1.0890985235913731e-05
# 1.9123246794746108e-05

# %%
print(np.var(mon_norm_anom_.dur))
print(np.var(tue_norm_anom_.dur))
print(np.var(wed_norm_anom_.dur))
print(np.var(thur_norm_anom_.dur))
print(np.var(fri_norm_anom_.dur))
# Out:
# 2.4481932978336052e-05
# 3.7050192561939973e-06
# 3.4390101813772977e-06
# 9.788221117514143e-08
# 6.3563329211688695e-06

# %%
print(np.var(mon_norm_anom.rate))
print(np.var(tue_norm_anom.rate))
print(np.var(wed_norm_anom.rate))
print(np.var(thur_norm_anom.rate))
print(np.var(fri_norm_anom.rate))
# Out:
# 0.08673136694071026
# 0.11186887217214339
# 0.11329702868823714
# 0.11429217054428563
# 0.0759706196935581

# %%
print(np.var(mon_norm_anom_.rate))
print(np.var(tue_norm_anom_.rate))
print(np.var(wed_norm_anom_.rate))
print(np.var(thur_norm_anom_.rate))
print(np.var(fri_norm_anom_.rate))
# Out:
# 0.10086007352265103
# 0.06100670528521824
# 0.05784358339715712
# 0.06406686822328447
# 0.12505435510639573

# %%
print(np.mean(mon_normalized.Rate))
print(np.mean(tue_normalized.Rate))
print(np.mean(wed_normalized.Rate))
print(np.mean(thur_normalized.Rate))
print(np.mean(fri_normalized.Rate))
# Out:
# 0.9534591800999453
# 0.9682464180482766
# 0.963487909007719
# 0.9520130854177479
# 0.9463800558141419

# %%
print(np.std(mon_normalized.Rate))
print(np.std(tue_normalized.Rate))
print(np.std(wed_normalized.Rate))
print(np.std(thur_normalized.Rate))
print(np.std(fri_normalized.Rate))
# Out:
# 0.1719545499635856
# 0.13629631401236408
# 0.14355987085345634
# 0.15476238461610103
# 0.18100667570286488

# %%
print(np.mean(mon_intersection.Rate))
print(np.mean(tue_intersection.Rate))
print(np.mean(wed_intersection.Rate))
print(np.mean(thur_intersection.Rate))
print(np.mean(fri_intersection.Rate))
# Out:
# 0.41840023176598623
# 0.5123340837310666
# 0.5013708292562775
# 0.29423990484778667
# 0.18847422932514435

# %%
print(np.std(mon_intersection.Rate))
print(np.std(tue_intersection.Rate))
print(np.std(wed_intersection.Rate))
print(np.std(thur_intersection.Rate))
print(np.std(fri_intersection.Rate))
# Out:
# 0.3260872349559727
# 0.31433015720809354
# 0.29763496375315934
# 0.37868515759466254
# 0.18180571975584972

# %%
print(np.std(mon_norm_anom.Rate))
print(np.std(tue_norm_anom.Rate))
print(np.std(wed_norm_anom.Rate))
print(np.std(thur_norm_anom.Rate))
print(np.std(fri_norm_anom.Rate))
# Out:
# 0.29450189632786794
# 0.3344680435738867
# 0.3365962398605147
# 0.3380712506917523
# 0.2756276831045062

# %%
print(np.mean(mon_norm_anom.Rate))
print(np.mean(tue_norm_anom.Rate))
print(np.mean(wed_norm_anom.Rate))
print(np.mean(thur_norm_anom.Rate))
print(np.mean(fri_norm_anom.Rate))
# Out:
# 0.5002332762918875
# 0.48198776244355246
# 0.4393166181575852
# 0.3868038059462241
# 0.39371272525269024

# %%
print(np.std(mon_norm_anom_.Rate))
print(np.std(tue_norm_anom_.Rate))
print(np.std(wed_norm_anom_.Rate))
print(np.std(thur_norm_anom_.Rate))
print(np.std(fri_norm_anom_.Rate))
# Out:
# 0.31758475014183385
# 0.24699535478469678
# 0.24050693003977477
# 0.25311433824120766
# 0.35363025196721465

# %%
print(np.mean(mon_norm_anom_.Rate))
print(np.mean(tue_norm_anom_.Rate))
print(np.mean(wed_norm_anom_.Rate))
print(np.mean(thur_norm_anom_.Rate))
print(np.mean(fri_norm_anom_.Rate))
# Out:
# 0.8128541119016673
# 0.8922908480077721
# 0.8829908279401605
# 0.9082720712674596
# 0.8079964962923007

# %%
print(np.mean(mon_norm_anom.pkts))
print(np.mean(tue_norm_anom.pkts))
print(np.mean(wed_norm_anom.pkts))
print(np.mean(thur_norm_anom.pkts))
print(np.mean(fri_norm_anom.pkts))
# Out:
# 0.013677298350420367
# 0.014606339513276015
# 0.015775280480307692
# 0.015234167849071405
# 0.01659423063657703

# %%
print(np.mean(mon_norm_anom_.pkts))
print(np.mean(tue_norm_anom_.pkts))
print(np.mean(wed_norm_anom_.pkts))
print(np.mean(thur_norm_anom_.pkts))
print(np.mean(fri_norm_anom_.pkts))
# Out:
# 0.0039652726698487595
# 0.0025671106705594895
# 0.0039086786562647045
# 0.0020814539678893785
# 0.003943639935003778

# %%
print(np.mean(mon_norm_anom.dur))
print(np.mean(tue_norm_anom.dur))
print(np.mean(wed_norm_anom.dur))
print(np.mean(thur_norm_anom.dur))
print(np.mean(fri_norm_anom.dur))
# Out:
# 0.006562598168363294
# 0.003658482528522115
# 0.0029407161634163194
# 0.0016781265565263858
# 0.0034959330058268226

# %%
print(np.mean(mon_norm_anom_.dur))
print(np.mean(tue_norm_anom_.dur))
print(np.mean(wed_norm_anom_.dur))
print(np.mean(thur_norm_anom_.dur))
print(np.mean(fri_norm_anom_.dur))
# Out:
# 0.001435736364704005
# 0.0005148157516804853
# 0.0005394205040254554
# 6.037771315459409e-05
# 0.0005681994381291165

# %%
print(np.mean(mon_norm_anom.rate))
print(np.mean(tue_norm_anom.rate))
print(np.mean(wed_norm_anom.rate))
print(np.mean(thur_norm_anom.rate))
print(np.mean(fri_norm_anom.rate))
# Out:
# 0.5002332762918875
# 0.48198776244355246
# 0.4393166181575852
# 0.3868038059462241
# 0.39371272525269024

# %%
print(np.mean(mon_norm_anom_.rate))
print(np.mean(tue_norm_anom_.rate))
print(np.mean(wed_norm_anom_.rate))
print(np.mean(thur_norm_anom_.rate))
print(np.mean(fri_norm_anom_.rate))
# Out:
# 0.8128541119016673
# 0.8922908480077721
# 0.8829908279401605
# 0.9082720712674596
# 0.8079964962923007

# %%
mon_intersection
# Out:
# 0.8643351137060722
